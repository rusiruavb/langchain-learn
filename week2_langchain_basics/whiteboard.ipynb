# %% [markdown]
# # Week 2: LangChain Basics - Whiteboard
#
# **Instructor-Led Session Workspace**

# %% [markdown]
# ### Setup

# %%
# Import required libraries

# %% [markdown]
# ### Introduction to LangChain

# %%
# Code implementation here

# %% [markdown]
# ### Chat Models with Messages

# %%
# Code implementation here

# %% [markdown]
# ### Simple Prompt Template

# %%
# Code implementation here

# %% [markdown]
# ### Chat Prompt Template

# %%
# Code implementation here

# %% [markdown]
# ### String Output Parser

# %%
# Code implementation here

# %% [markdown]
# ### JSON Output Parser

# %%
# Code implementation here

# %% [markdown]
# ### Pydantic Output Parser (Structured Outputs)

# %%
# Code implementation here

# %% [markdown]
# ### LCEL - Simple Chain (Pipe Operator |)

# %%
# Code implementation here

# %% [markdown]
# ### Sequential Chain (Multi-Step)

# %%
# Code implementation here

# %% [markdown]
# ### RunnablePassthrough

# %%
# Code implementation here

# %% [markdown]
# ### RunnablePassthrough.assign()

# %%
# Code implementation here

# %% [markdown]
# ### RunnableLambda (Custom Functions)

# %%
# Code implementation here

# %% [markdown]
# ### RunnableParallel (Concurrent Execution)

# %%
# Code implementation here

# %% [markdown]
# ### ConversationBufferMemory

# %%
# Code implementation here

# %% [markdown]
# ### ConversationBufferWindowMemory

# %%
# Code implementation here

# %% [markdown]
# ### ConversationSummaryMemory

# %%
# Code implementation here

# %% [markdown]
# ### Custom Memory with LCEL

# %%
# Code implementation here

# %% [markdown]
# ### Complete Example - Email Assistant Chain

# %%
# Code implementation here

# %% [markdown]
# ### Free Coding Space
