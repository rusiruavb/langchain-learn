# %% [markdown]
# ### Setup

# %%
# Import required libraries

# %% [markdown]
# ### First LLM API Call

# %%
# Code implementation here

# %% [markdown]
# ### Destructuring the LLM Response Object

# %%
# Code implementation here

# %% [markdown]
# ### Temperature Change (🔥❄️)

# %%
# Code implementation here

# %% [markdown]
# ### System Prompt

# %%
# Code implementation here

# %% [markdown]
# ### Conversation History & Memory 🧠

# %%
# Code implementation here

# %% [markdown]
# ### Streaming

# %%
# Code implementation here

# %% [markdown]
# ### Prompt Engineering Basics

# %%
# Code implementation here
